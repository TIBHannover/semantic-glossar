# %% [markdown]
# ---
# title: "Sandbox"
# jupyter: python3
# code-fold: true
# execute:
#   echo: false
#   output: asis
# ---

# %%
from datetime import datetime
import sys
import time
import requests
import html
import locale


locale.setlocale(locale.LC_ALL,"") 
#locale "de_DE" needs to be set as default on whichever system you run this notebook on
#otherwise the umlaute sorting won't work



api_url = "https://climatekg.semanticclimate.net/api.php"

def fetch_mediawiki_data(api_url, params, session):
    try:
        response = session.get(api_url, params=params)
        response.raise_for_status()  # Raise an exception for HTTP errors
        data = response.json()
        return data
    except requests.exceptions.RequestException as e:
        print(f"Error fetching data from MediaWiki API: {e}")
        return None

def extract_items(data):
    items = []
    results = data.get("query", {}).get("results", {})
    
    for item_id, item_data in results.items():
        #print(item_data)
        
        

        multilang_fields = ["description"]
        entity_fields = ["subCategoryOf", "synonyms", "similarTo"]
        txt_fields = ["term","description_plain","vocabulary","acronym","tags","status"]
        item = {
            "id": item_id
        }

        for fieldname in txt_fields:
            if item_data["printouts"].get(fieldname, [{}]):
                #print(fieldname)
                item[fieldname] = item_data["printouts"].get(fieldname, [None])[0]
            else:
                item[fieldname] = ""
        
        for fieldname in entity_fields:
            if item_data["printouts"].get(fieldname, [{}]):
                entities = item_data["printouts"].get(fieldname, [])
                # Check if entity is a dictionary and has the 'fulltext' key
                item[fieldname] = ", ".join(
                    [entity.get('fulltext', '') if isinstance(entity, dict) else str(entity) for entity in entities]
                )
        # Create a lowercase version of the same
                item[f"{fieldname}_lowercase"] = ", ".join(
                    [entity.get('fulltext', '').lower().replace(" ", "-") if isinstance(entity, dict) else str(entity).lower().replace(" ", "-") for entity in entities]
                )
    
                # Create a list of individual links
                links = [
                    f"[{entity.get('fulltext', '')}](/sandbox.html#{entity.get('fulltext', '').lower().replace(' ', '-')})"
                    if isinstance(entity, dict)
                    else f"[{str(entity)}](/sandbox.html#{str(entity).lower().replace(' ', '-')})"
                    for entity in entities
                ]
                
                # Join the links with commas
                item[f"{fieldname}_links"] = ", ".join(links)
            else:
                item[fieldname] = ""
                item[f"{fieldname}_links"] = ""


        for fieldname in multilang_fields:
            if item_data["printouts"].get(fieldname, [{}]):
                #print(fieldname)
                item[fieldname] = item_data["printouts"].get(fieldname, [{}])[0].get("Text", {}).get("item", [None])[0]
            else:
                item[fieldname] = ""
        
        if item["status"]:
            translate = {
                "Draft":"Entwurf",
                "Pending Review":"Review ausstehend",
                "Published":"Veröffentlicht",
                "Unpublished":"Unveröffentlicht"
            }
            for t in translate:
                if item["status"] == t:
                    item["status"] = translate[t]
        items.append(item)
    
    return items



def generate_html_span(items, vocabulary):
    items = sorted(items, key=lambda t: locale.strxfrm(t['term']))    
    html = f''      
    for item in items:
        if f'({item["status"]}' != "Unveröffentlicht":
            html += f'''     
        
---

### <span class="gloss-term-all gloss-term">{item["term"]}</span> 

<span class="gloss-term-all gloss-definition">{item["description"]}</span>
           '''

            if item.get("description_plain"):
                html += f'''
**<span class="gloss-term-all gloss-cl-definition-label">Beschreibung (einfach):</span>**

<span class="gloss-term-all gloss-cl-definition">{item["description_plain"]}</span>
                ''' 

            if item.get("acronym"):
                html += f'''
**<span class="gloss-term-all gloss-acronym-label">Akronyme:</span>**  
      
<span class="gloss-term-all gloss-acronym">{item["acronym"]}</span>
                '''
            if item.get("status"):
                html += f'''
**<span class="gloss-term-all gloss-status-label">Status:</span>**  
      
<span class="gloss-term-all gloss-status">{item["status"]}</span>
                '''

            if item.get("tags"):
                html += f'''
**<span class="gloss-term-all gloss-tag-label">Tags:</span>**
      
<span class="gloss-term-all gloss-tag">{item["tags"]}</span>
                '''

            if item.get("similarTo"):
                html += f'''
**<span class="gloss-term-all gloss-similar-tag gloss-similar-label">Verwandt:</span>**
      
<span class="gloss-term-all gloss-similarto">{item["similarTo_links"]}</span>
                '''

            if item.get("subCategoryOf"):
                html += f'''
**<span class="gloss-term-all gloss-subclass-tag gloss-subclass-label">Unterbegriff von:</span>**
      
<span class="gloss-term-all gloss-subCategoryOf">{item["subCategoryOf_links"]}</span>

                '''

            if item.get("synonyms"):
                html += f'''
**<span class="gloss-term-all gloss-synonyme-tag gloss-synonyme-label">Synonyme:</span>**
      
<span class="gloss-term-all gloss-synonym">{item['synonyms_links']}</span>

            
                '''
        else:
            html += ""
    return html

def login(api_url, username, password):
    session = requests.Session()
    
    # Step 1: GET request to fetch login token
    login_token_params = {
        'action': 'query',
        'meta': 'tokens',
        'type': 'login',
        'format': 'json'
    }
    response = session.get(api_url, params=login_token_params)
    response.raise_for_status()
    login_token = response.json()['query']['tokens']['logintoken']
    
    # Step 2: POST request to log in
    login_params = {
        'action': 'login',
        'lgname': username,
        'lgpassword': password,
        'lgtoken': login_token,
        'format': 'json'
    }
    response = session.post(api_url, data=login_params)
    response.raise_for_status()
    login_result = response.json()
    
    if login_result['login']['result'] == 'Success':
        #print('Logged in successfully')
        return session
    else:
        print('Failed to log in')
        sys.exit(1)

def get_glossary(vocabulary, session):

    params = {
        'action': 'ask',
        'query': f'[[Item:+]] [[has subobject::+]] [[P1::Term]] [[P18::{vocabulary}]] [[P20::!Unveröffentlicht]]|?Wikibase description=description |?P26=description_plain |?P3=term |?P10.P3=subCategoryOf |?P20=status |?P21.P3=acronym |?P22=tags |?P23.P3=similarTo |?P18=vocabulary |?P24.P3=synonyms |sort=P3 |limit=10000',
        'format': 'json'
    }

    response = fetch_mediawiki_data(api_url, params, session)
    items = extract_items(response)
    
    if items:
        # Generate the HTML for the table
        html = '<html><head><link rel="stylesheet" href="glossary.css"></head><body>\n\n'
        #html += generate_html_table(items)
        html += generate_html_span(items,vocabulary)
        html += '\n</body></html>'
        print(html)

# %%
username = 'reader'  # Replace with your username
password = 'readonly'  # Replace with your password

session = login(api_url, username, password)
get_glossary("Sandbox", session)
# Out:
# <html><head><link rel="stylesheet" href="glossary.css"></head><body>
#
#
#
# ---
#
# ### <span class="gloss-term-all gloss-term">addfsdfsd</span>
#
# <span class="gloss-term-all gloss-definition">sdfsdf</span>
#
# **<span class="gloss-term-all gloss-cl-definition-label">Beschreibung (einfach):</span>**
#
# <span class="gloss-term-all gloss-cl-definition">sdfsdfsd</span>
#
# **<span class="gloss-term-all gloss-status-label">Status:</span>**
#
# <span class="gloss-term-all gloss-status">Entwurf</span>
#
# **<span class="gloss-term-all gloss-similar-tag gloss-similar-label">Verwandt:</span>**
#
# <span class="gloss-term-all gloss-similarto">[black carbon](https://tibhannover.github.io/semantic-glossar/sandbox.html#black-carbon)</span>
#
# **<span class="gloss-term-all gloss-subclass-tag gloss-subclass-label">Unterbegriff von:</span>**
#
# <span class="gloss-term-all gloss-subCategoryOf">[Gordon Shumway](https://tibhannover.github.io/semantic-glossar/sandbox.html#gordon-shumway)</span>
#
#
# **<span class="gloss-term-all gloss-synonyme-tag gloss-synonyme-label">Synonyme:</span>**
#
# <span class="gloss-term-all gloss-synonym">[black carbon](https://tibhannover.github.io/semantic-glossar/sandbox.html#black-carbon)</span>
#
#
#
#
# ---
#
# ### <span class="gloss-term-all gloss-term">Begriff</span>
#
# <span class="gloss-term-all gloss-definition">Beschreibung</span>
#
# **<span class="gloss-term-all gloss-status-label">Status:</span>**
#
# <span class="gloss-term-all gloss-status">Entwurf</span>
#
#
# ---
#
# ### <span class="gloss-term-all gloss-term">Begriff2</span>
#
# <span class="gloss-term-all gloss-definition">Beschreibung</span>
#
# **<span class="gloss-term-all gloss-status-label">Status:</span>**
#
# <span class="gloss-term-all gloss-status">Entwurf</span>
#
# **<span class="gloss-term-all gloss-tag-label">Tags:</span>**
#
# <span class="gloss-term-all gloss-tag">Monday</span>
#
# **<span class="gloss-term-all gloss-subclass-tag gloss-subclass-label">Unterbegriff von:</span>**
#
# <span class="gloss-term-all gloss-subCategoryOf">[Katze](https://tibhannover.github.io/semantic-glossar/sandbox.html#katze)</span>
#
#
#
# ---
#
# ### <span class="gloss-term-all gloss-term">Bishopskin</span>
#
# <span class="gloss-term-all gloss-definition">Band aus London</span>
#
# **<span class="gloss-term-all gloss-status-label">Status:</span>**
#
# <span class="gloss-term-all gloss-status">Entwurf</span>
#
#
# ---
#
# ### <span class="gloss-term-all gloss-term">dssdfdf</span>
#
# <span class="gloss-term-all gloss-definition">sdsdfsdfs</span>
#
# **<span class="gloss-term-all gloss-cl-definition-label">Beschreibung (einfach):</span>**
#
# <span class="gloss-term-all gloss-cl-definition">sdfsdfsdf</span>
#
# **<span class="gloss-term-all gloss-status-label">Status:</span>**
#
# <span class="gloss-term-all gloss-status">Entwurf</span>
#
# **<span class="gloss-term-all gloss-similar-tag gloss-similar-label">Verwandt:</span>**
#
# <span class="gloss-term-all gloss-similarto">[black carbon](https://tibhannover.github.io/semantic-glossar/sandbox.html#black-carbon)</span>
#
# **<span class="gloss-term-all gloss-synonyme-tag gloss-synonyme-label">Synonyme:</span>**
#
# <span class="gloss-term-all gloss-synonym">[black carbon](https://tibhannover.github.io/semantic-glossar/sandbox.html#black-carbon)</span>
#
#
#
#
# ---
#
# ### <span class="gloss-term-all gloss-term">Globalisation</span>
#
# <span class="gloss-term-all gloss-definition">Economic policy of extending supply chains.</span>
#
# **<span class="gloss-term-all gloss-cl-definition-label">Beschreibung (einfach):</span>**
#
# <span class="gloss-term-all gloss-cl-definition">Economic policy of extending supply chains.</span>
#
# **<span class="gloss-term-all gloss-status-label">Status:</span>**
#
# <span class="gloss-term-all gloss-status">Entwurf</span>
#
#
# ---
#
# ### <span class="gloss-term-all gloss-term">Grigori Jefimowitsch Rasputin</span>
#
# <span class="gloss-term-all gloss-definition">Rasputin ist einer der bekanntesten Namen in der Geschichte Russlands.  Über ihn gibt es eine Vielzahl von Biographien, Romanen, Spiel- und Dokumentarfilmen sowie Theaterstücken, Opern und Musicals. Unzählige Bars, Restaurants und Nachtclubs sind nach ihm benannt.  Er ist die Hauptfigur in mindestens zwei Videospielen und erscheint in japanischen Manga- und Anime-Produktionen.</span>
#
# **<span class="gloss-term-all gloss-status-label">Status:</span>**
#
# <span class="gloss-term-all gloss-status">Entwurf</span>
#
#
# ---
#
# ### <span class="gloss-term-all gloss-term">Hund</span>
#
# <span class="gloss-term-all gloss-definition">Säugetier mit vier Beinen und zwei Ohren.</span>
#
# **<span class="gloss-term-all gloss-status-label">Status:</span>**
#
# <span class="gloss-term-all gloss-status">Entwurf</span>
#
#
# ---
#
# ### <span class="gloss-term-all gloss-term">Katze</span>
#
# <span class="gloss-term-all gloss-definition">Tier, meistens etwas kleiner als ein Hund</span>
#
# **<span class="gloss-term-all gloss-status-label">Status:</span>**
#
# <span class="gloss-term-all gloss-status">Entwurf</span>
#
# **<span class="gloss-term-all gloss-similar-tag gloss-similar-label">Verwandt:</span>**
#
# <span class="gloss-term-all gloss-similarto">[Pferd](https://tibhannover.github.io/semantic-glossar/sandbox.html#pferd), [Waschbär](https://tibhannover.github.io/semantic-glossar/sandbox.html#waschbär), [Hund](https://tibhannover.github.io/semantic-glossar/sandbox.html#hund)</span>
#
#
# ---
#
# ### <span class="gloss-term-all gloss-term">Kilgore Trout</span>
#
# <span class="gloss-term-all gloss-definition">Fiktionaler Schriftsteller</span>
#
# **<span class="gloss-term-all gloss-status-label">Status:</span>**
#
# <span class="gloss-term-all gloss-status">In Review</span>
#
# **<span class="gloss-term-all gloss-synonyme-tag gloss-synonyme-label">Synonyme:</span>**
#
# <span class="gloss-term-all gloss-synonym">[Theodore Sturgeon](https://tibhannover.github.io/semantic-glossar/sandbox.html#theodore-sturgeon)</span>
#
#
#
#
# ---
#
# ### <span class="gloss-term-all gloss-term">Kinsbishop</span>
#
# <span class="gloss-term-all gloss-definition">UK BAND</span>
#
# **<span class="gloss-term-all gloss-status-label">Status:</span>**
#
# <span class="gloss-term-all gloss-status">Entwurf</span>
#
# **<span class="gloss-term-all gloss-tag-label">Tags:</span>**
#
# <span class="gloss-term-all gloss-tag">Player</span>
#
# **<span class="gloss-term-all gloss-subclass-tag gloss-subclass-label">Unterbegriff von:</span>**
#
# <span class="gloss-term-all gloss-subCategoryOf">[Bishopskin](https://tibhannover.github.io/semantic-glossar/sandbox.html#bishopskin)</span>
#
#
#
# ---
#
# ### <span class="gloss-term-all gloss-term">Link</span>
#
# <span class="gloss-term-all gloss-definition">About the link [https://link.com/](https://link.com/)</span>
#
# **<span class="gloss-term-all gloss-status-label">Status:</span>**
#
# <span class="gloss-term-all gloss-status">Entwurf</span>
#
#
# ---
#
# ### <span class="gloss-term-all gloss-term">long descr test</span>
#
# <span class="gloss-term-all gloss-definition">...</span>
#
# **<span class="gloss-term-all gloss-status-label">Status:</span>**
#
# <span class="gloss-term-all gloss-status">Entwurf</span>
#
#
# ---
#
# ### <span class="gloss-term-all gloss-term">Pferd</span>
#
# <span class="gloss-term-all gloss-definition">Vierbeiniges Säugetier</span>
#
# **<span class="gloss-term-all gloss-cl-definition-label">Beschreibung (einfach):</span>**
#
# <span class="gloss-term-all gloss-cl-definition">Vierbeiniges Säugetier</span>
#
# **<span class="gloss-term-all gloss-status-label">Status:</span>**
#
# <span class="gloss-term-all gloss-status">Entwurf</span>
#
#
# ---
#
# ### <span class="gloss-term-all gloss-term">sdfsdf</span>
#
# <span class="gloss-term-all gloss-definition">sdfsdf</span>
#
# **<span class="gloss-term-all gloss-cl-definition-label">Beschreibung (einfach):</span>**
#
# <span class="gloss-term-all gloss-cl-definition">sdfsdf</span>
#
# **<span class="gloss-term-all gloss-status-label">Status:</span>**
#
# <span class="gloss-term-all gloss-status">Entwurf</span>
#
#
# ---
#
# ### <span class="gloss-term-all gloss-term">sfsd</span>
#
# <span class="gloss-term-all gloss-definition">sdf</span>
#
# **<span class="gloss-term-all gloss-cl-definition-label">Beschreibung (einfach):</span>**
#
# <span class="gloss-term-all gloss-cl-definition">dsf</span>
#
# **<span class="gloss-term-all gloss-status-label">Status:</span>**
#
# <span class="gloss-term-all gloss-status">Entwurf</span>
#
#
# ---
#
# ### <span class="gloss-term-all gloss-term">Staatsvertrag</span>
#
# <span class="gloss-term-all gloss-definition">Ein Staatsvertrag ist ein Vertrag, bei dem mindestens einer der Vertragspartner ein staatliches Organ ist.</span>
#
# **<span class="gloss-term-all gloss-status-label">Status:</span>**
#
# <span class="gloss-term-all gloss-status">Entwurf</span>
#
# **<span class="gloss-term-all gloss-similar-tag gloss-similar-label">Verwandt:</span>**
#
# <span class="gloss-term-all gloss-similarto">[APEC](https://tibhannover.github.io/semantic-glossar/sandbox.html#apec), [APP](https://tibhannover.github.io/semantic-glossar/sandbox.html#app)</span>
#
# **<span class="gloss-term-all gloss-subclass-tag gloss-subclass-label">Unterbegriff von:</span>**
#
# <span class="gloss-term-all gloss-subCategoryOf">[APEC](https://tibhannover.github.io/semantic-glossar/sandbox.html#apec)</span>
#
#
# **<span class="gloss-term-all gloss-synonyme-tag gloss-synonyme-label">Synonyme:</span>**
#
# <span class="gloss-term-all gloss-synonym">[APEC](https://tibhannover.github.io/semantic-glossar/sandbox.html#apec)</span>
#
#
#
#
# ---
#
# ### <span class="gloss-term-all gloss-term">Test</span>
#
# <span class="gloss-term-all gloss-definition">Test</span>
#
# **<span class="gloss-term-all gloss-status-label">Status:</span>**
#
# <span class="gloss-term-all gloss-status">Entwurf</span>
#
#
# ---
#
# ### <span class="gloss-term-all gloss-term">test111</span>
#
# <span class="gloss-term-all gloss-definition">test</span>
#
# **<span class="gloss-term-all gloss-status-label">Status:</span>**
#
# <span class="gloss-term-all gloss-status">Entwurf</span>
#
#
# ---
#
# ### <span class="gloss-term-all gloss-term">testTermasdsdsdsdfdsf</span>
#
# <span class="gloss-term-all gloss-definition">sdfsdfsdsdfs</span>
#
# **<span class="gloss-term-all gloss-status-label">Status:</span>**
#
# <span class="gloss-term-all gloss-status">Review ausstehend</span>
#
#
# ---
#
# ### <span class="gloss-term-all gloss-term">testTermUmlaute</span>
#
# <span class="gloss-term-all gloss-definition">Eine Gefahr, wie z.B: ein Hochwasser kann zu Schäden führen</span>
#
# **<span class="gloss-term-all gloss-status-label">Status:</span>**
#
# <span class="gloss-term-all gloss-status">Entwurf</span>
#
#
# ---
#
# ### <span class="gloss-term-all gloss-term">testTermX</span>
#
# <span class="gloss-term-all gloss-definition">Beschreibung</span>
#
# **<span class="gloss-term-all gloss-cl-definition-label">Beschreibung (einfach):</span>**
#
# <span class="gloss-term-all gloss-cl-definition">Klartext</span>
#
# **<span class="gloss-term-all gloss-status-label">Status:</span>**
#
# <span class="gloss-term-all gloss-status">Entwurf</span>
#
#
# ---
#
# ### <span class="gloss-term-all gloss-term">The Gun Club</span>
#
# <span class="gloss-term-all gloss-definition">Amerikanische Band</span>
#
# **<span class="gloss-term-all gloss-status-label">Status:</span>**
#
# <span class="gloss-term-all gloss-status">Entwurf</span>
#
#
# ---
#
# ### <span class="gloss-term-all gloss-term">Theodore Sturgeon</span>
#
# <span class="gloss-term-all gloss-definition">Realer Schriftsteller</span>
#
# **<span class="gloss-term-all gloss-status-label">Status:</span>**
#
# <span class="gloss-term-all gloss-status">Entwurf</span>
#
# **<span class="gloss-term-all gloss-synonyme-tag gloss-synonyme-label">Synonyme:</span>**
#
# <span class="gloss-term-all gloss-synonym">[Kilgore Trout](https://tibhannover.github.io/semantic-glossar/sandbox.html#kilgore-trout)</span>
#
#
#
#
# ---
#
# ### <span class="gloss-term-all gloss-term">Waschbär</span>
#
# <span class="gloss-term-all gloss-definition">Mittelgroßes Tier mit Streifen und Panzerknackermaske</span>
#
# **<span class="gloss-term-all gloss-status-label">Status:</span>**
#
# <span class="gloss-term-all gloss-status">Entwurf</span>
#
#
# ---
#
# ### <span class="gloss-term-all gloss-term">Wasser</span>
#
# <span class="gloss-term-all gloss-definition">Etwa 70% von dir, mir, Bello und unserem blauen Planeten</span>
#
# **<span class="gloss-term-all gloss-status-label">Status:</span>**
#
# <span class="gloss-term-all gloss-status">Entwurf</span>
#
# </body></html>
